# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('spotify-albums_data_2023.csv')
df1
# Out:
#                  track_name                track_id  track_number  \
# 0             Amazing Grace  6mN8nzCXWUeT5LWEcG1Utx             5
# 1              Silent Night  58sgjtx3FOnBBEOd3BQE6C             8
# 2           Ancient Canyons  45tQJhm0WSk5VWMZK3FsLK             1
# 3       Pacha Mama Medicina  3VFD7QqkJSg0OR6yBwKl7A             6
# 4           Palace Of Light  7LwJV5BEIC9BQnzvaBSyCc             7
# ...                     ...                     ...           ...
# 438968       Where She Goes  2sTDlCxmuZCTDKKk9f1qus            17
# 438969            Europa :(  6vh4S1z08AjGipGAEsV62e            20
# 438970                 Seda  1YnChEM51BVZ5dRhbVFEMl             8
# 438971           Un Preview  5ixdmTpCmH5diBA1j154wN            22
# 438972      Mercedes Carota  3TYOH7ta0101NYssoH5GlU            12
#
#         duration_ms album_type  artists  total_tracks  \
# 0            555521      album      NaN             9
# 1            535041      album      NaN             9
# ...

# %%
df1 = df1[['track_name', 'track_id', 'duration_ms', 'album_name', 'release_date','label', 'album_popularity', 'album_id', 'artist_id', 'duration_sec']]

# %%
df1
# Out:
#                  track_name                track_id  duration_ms  \
# 0             Amazing Grace  6mN8nzCXWUeT5LWEcG1Utx       555521
# 1              Silent Night  58sgjtx3FOnBBEOd3BQE6C       535041
# 2           Ancient Canyons  45tQJhm0WSk5VWMZK3FsLK       545855
# 3       Pacha Mama Medicina  3VFD7QqkJSg0OR6yBwKl7A       305241
# 4           Palace Of Light  7LwJV5BEIC9BQnzvaBSyCc       351060
# ...                     ...                     ...          ...
# 438968       Where She Goes  2sTDlCxmuZCTDKKk9f1qus       231704
# 438969            Europa :(  6vh4S1z08AjGipGAEsV62e        11904
# 438970                 Seda  1YnChEM51BVZ5dRhbVFEMl       190476
# 438971           Un Preview  5ixdmTpCmH5diBA1j154wN       165582
# 438972      Mercedes Carota  3TYOH7ta0101NYssoH5GlU       202635
#
#                                  album_name             release_date  \
# 0                     Deep Peace Experience  2015-06-09 00:00:00 UTC
# ...

# %%
df1.isna().sum()
# Out:
# track_name           2
# track_id             0
# duration_ms          0
# album_name           0
# release_date        23
# label               24
# album_popularity     0
# album_id             0
# artist_id            0
# duration_sec         0
# dtype: int64

# %%
df1.to_csv('Albums_cleaned.csv')

# %%
df2 = pd.read_csv('spotify_artist_data_2023.csv')

# %%
df2
# Out:
#                            id                   name  artist_popularity  \
# 0      6GkSLJj5CGLIckLIb8J4LR      Late Night Fights                  0
# 1      1N0VwQy5PRJymrRvlRzDIj       Sub Par All Star                  0
# 2      4Ch4BIKKwMJsiu1oVLDwpX  Nirvana Meditation 8D                  0
# 3      5h2iINTOvhghVcpIzrztPP      Red Hot Rebellion                  0
# 4      7dE2MLL2SaI6MujpU5HFVi   Nirvana Tribute Band                  0
# ...                       ...                    ...                ...
# 37007  12GqGscKJx3aE4t07u7eVZ             Peso Pluma                 90
# 37008  1Xyo4u8uXC1ZmMpatF05PJ             The Weeknd                 93
# 37009  4q3ewBCX7sLwd24euuV69X              Bad Bunny                 95
# 37010  3TVXtAsR1Inumwj472S9r4                  Drake                 95
# 37011  06HL4z0CvFAxyc27GXpf02           Taylor Swift                100
#
#                                            artist_genres  followers  \
# ...

# %%
df2.isna().sum()
# Out:
# id                       0
# name                     0
# artist_popularity        0
# artist_genres            0
# followers                0
# genre_0              26065
# genre_1              32192
# genre_2              34572
# genre_3              35647
# genre_4              36294
# genre_5              37012
# genre_6              37012
# dtype: int64

# %%
df2 = df2[['id', 'name', 'artist_popularity', 'followers', 'genre_0']]

# %%
df2
# Out:
#                            id                   name  artist_popularity  \
# 0      6GkSLJj5CGLIckLIb8J4LR      Late Night Fights                  0
# 1      1N0VwQy5PRJymrRvlRzDIj       Sub Par All Star                  0
# 2      4Ch4BIKKwMJsiu1oVLDwpX  Nirvana Meditation 8D                  0
# 3      5h2iINTOvhghVcpIzrztPP      Red Hot Rebellion                  0
# 4      7dE2MLL2SaI6MujpU5HFVi   Nirvana Tribute Band                  0
# ...                       ...                    ...                ...
# 37007  12GqGscKJx3aE4t07u7eVZ             Peso Pluma                 90
# 37008  1Xyo4u8uXC1ZmMpatF05PJ             The Weeknd                 93
# 37009  4q3ewBCX7sLwd24euuV69X              Bad Bunny                 95
# 37010  3TVXtAsR1Inumwj472S9r4                  Drake                 95
# 37011  06HL4z0CvFAxyc27GXpf02           Taylor Swift                100
#
#        followers                    genre_0
# 0            184           minneapolis punk
# ...

# %%
df2.columns = ['id', 'artist_name', 'artist_popularity','followers','genre']

# %%
df2
# Out:
#                            id            artist_name  artist_popularity  \
# 0      6GkSLJj5CGLIckLIb8J4LR      Late Night Fights                  0
# 1      1N0VwQy5PRJymrRvlRzDIj       Sub Par All Star                  0
# 2      4Ch4BIKKwMJsiu1oVLDwpX  Nirvana Meditation 8D                  0
# 3      5h2iINTOvhghVcpIzrztPP      Red Hot Rebellion                  0
# 4      7dE2MLL2SaI6MujpU5HFVi   Nirvana Tribute Band                  0
# ...                       ...                    ...                ...
# 37007  12GqGscKJx3aE4t07u7eVZ             Peso Pluma                 90
# 37008  1Xyo4u8uXC1ZmMpatF05PJ             The Weeknd                 93
# 37009  4q3ewBCX7sLwd24euuV69X              Bad Bunny                 95
# 37010  3TVXtAsR1Inumwj472S9r4                  Drake                 95
# 37011  06HL4z0CvFAxyc27GXpf02           Taylor Swift                100
#
#        followers                      genre
# 0            184           minneapolis punk
# ...

# %%
df2.to_csv('Artists_cleaned.csv')

# %%
df3 = pd.read_csv('spotify_tracks_data_2023.csv')

# %%
df3
# Out:
#                             id  track_popularity  explicit
# 0       02MBhqgR7WeeI4ZfB6Lo0i                 0     False
# 1       5j4M4gLYuUy9PVw0vsXWyq                 0     False
# 2       46EucLPJpx0QM3SCjzzdP0                 0     False
# 3       4nK2LvW3osgDT89S38Mcg6                 0     False
# 4       1Pq37WIQZDG7yNFnY5IbqG                 0     False
# ...                        ...               ...       ...
# 438933  4rXLjWdF2ZZpXCVTfWcshS                93      True
# 438934  7MXVkk9YMctZqd1Srtv4MB                94      True
# 438935  6uIIdjYTxxpWOyWuVXrKQO                95      True
# 438936  4MjDJD8cW7iVeWInc2Bdyj                96      True
# 438937  7iQXYTyuG13aoeHxGG28Nh                97      True
#
# [438938 rows x 3 columns]

# %%
df3 = df3[['id', 'track_popularity']]

# %%
df3
# Out:
#                             id  track_popularity
# 0       02MBhqgR7WeeI4ZfB6Lo0i                 0
# 1       5j4M4gLYuUy9PVw0vsXWyq                 0
# 2       46EucLPJpx0QM3SCjzzdP0                 0
# 3       4nK2LvW3osgDT89S38Mcg6                 0
# 4       1Pq37WIQZDG7yNFnY5IbqG                 0
# ...                        ...               ...
# 438933  4rXLjWdF2ZZpXCVTfWcshS                93
# 438934  7MXVkk9YMctZqd1Srtv4MB                94
# 438935  6uIIdjYTxxpWOyWuVXrKQO                95
# 438936  4MjDJD8cW7iVeWInc2Bdyj                96
# 438937  7iQXYTyuG13aoeHxGG28Nh                97
#
# [438938 rows x 2 columns]

# %%
df3.columns= ['track_id', 'track_popularity']

# %%
df3
# Out:
#                       track_id  track_popularity
# 0       02MBhqgR7WeeI4ZfB6Lo0i                 0
# 1       5j4M4gLYuUy9PVw0vsXWyq                 0
# 2       46EucLPJpx0QM3SCjzzdP0                 0
# 3       4nK2LvW3osgDT89S38Mcg6                 0
# 4       1Pq37WIQZDG7yNFnY5IbqG                 0
# ...                        ...               ...
# 438933  4rXLjWdF2ZZpXCVTfWcshS                93
# 438934  7MXVkk9YMctZqd1Srtv4MB                94
# 438935  6uIIdjYTxxpWOyWuVXrKQO                95
# 438936  4MjDJD8cW7iVeWInc2Bdyj                96
# 438937  7iQXYTyuG13aoeHxGG28Nh                97
#
# [438938 rows x 2 columns]

# %%
df3.isna().sum()
# Out:
# track_id            0
# track_popularity    0
# dtype: int64

# %%
df3.to_csv('Tracks_Cleaned.csv')
